# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 항상 억지 기법보다 모든문제에 더 효율적인 것은 아님.
#
# 8개의 숫자더하기
#
# 억지기법 : 7번의 덧셈 , 분할정복: 위그림 병합에서 7번 덧셈
#
# ## 따라서 두방법 동일, 분할 정복이 억지기법보다 모든 문제 효율적x
# 하지만 분할정복은 정렬이나 탐색과 같은 많은 중요한 문제에서 상당한 효과

# %% [markdown]
# ## 순환관계식(연속대치법) 분할정복 알고리즘들의 점근적 시간 복잡도 편리하게 구하는방법
# 분할정복기법은 n인 문제를 n/2크기의 두개의 문제로 나누지만 항상 그렇지x
#
# ## 크기가 n인문제 => b개의 같은 크기의 부분 문제
# ## 이들중에서 해결 필요x는 것을 제외하고 a개만 다시 해결해야 하는 경우
#
# ## 순환 관계식(연속 대치법)
#
# ![image.png](attachment:image.png)
#
# aT(n/b)은 크기가 n/b로 줄어든 문제 a개를 푸는데 걸리는 연산
#
# b>1, 1<=a, <=b 단순화를 위해  n= b^k이라 가정
#
# f(n) 문제를 부분문제들로 나누는 과정과 부분문제들의 해를 병합하여 최종해를 만드는대 사용되는 연산
#
#
#
# # 리스트 합구하기
# ![image-2.png](attachment:image-2.png)
#
#
# 주어진 문제의 숫자들을 2개 그룹으로 b=2
# 2개 그룹문제모두해결 a=2
# 2개 그룹 해가 구해지면 병합과정에서 이들을 한번 더해야 f(n) =1
# ![image-3.png](attachment:image-3.png)
#
# T(n/2)을 구해야되는데 n대신 n/2대입
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# n^log2^2
#
# ### 만약 T(n) = 2T(n/2) +n 이면 a=2 b=2 f(n) =n ∈ O(n) = O(n^1)이므로 d=1
# ### 따라서 2번째 2=2^1 -> a=b^d에 해당 O(n^1 log n) = nlogn
# ### 만약 T(n) =3T(n/2) + n^2이면 a=3 , b=2 , f(n)=n^2 ∈ O(n^2)=O(n^2) 이므로 d=2
# ### 따라서 1번째 3>2^2 -> a=b^d에 해당 O(n^2)
# ### 마스터 정리는 많은 순환 관계식의 점근적 복잡도 계산에 유용
#
# 모든 순환식에 적용x
